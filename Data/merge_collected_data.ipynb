# %% [markdown]
# ## Concatonate & Dedup Datasets

# %%
# Import packages
import os
import pandas as pd

# %% [markdown]
# #### Get pathways of all collected data

# %%
# Set pathway to get to collected data
data_path = '../Data_Collection/output'

# Instantiate lists to hold pathways for files of each topic
election_files = []
abrams_files = []
kemp_files = []

# Loop over all files of collected data and append file pathways to appropriate topic list
for file in os.listdir(data_path):
    complete_path = data_path + '/' + file
    if file.startswith('election'):
        election_files.append(complete_path)
    elif file.startswith('abrams'):
        abrams_files.append(complete_path)
    elif file.startswith('kemp'):
        kemp_files.append(complete_path)

# See lists of filepaths for each topic
print('General Election:\n', election_files)
print('Abrams:\n', abrams_files)
print('Kemp:\n', kemp_files)
# Out:
# General Election:
#  ['../Data_Collection/output/election_1030.csv', '../Data_Collection/output/election_1025.csv']
# Abrams:
#  ['../Data_Collection/output/abrams_1030.csv', '../Data_Collection/output/abrams_1025.csv']
# Kemp:
#  ['../Data_Collection/output/kemp_1030.csv', '../Data_Collection/output/kemp_1025.csv']

# %% [markdown]
# #### Concatonate and Dedup Datasets for Each Topic

# %%
# Get earliest date in election dataset
earliest_date_df = pd.read_csv('../Data_Collection/output/election_1025.csv')
earliest_date = min(pd.to_datetime(earliest_date_df['created_at']))
earliest_date
# Out:
# Timestamp('2022-10-17 08:10:19')

# %%
# Method to concatonate and deduplicate datasets
def handle_datasets(list_of_file_path, min_date):

    # Read in all csv files into single concatonated dataframe
    df = pd.concat(map(pd.read_csv, list_of_file_path), ignore_index=True)
    
    # Convert created_at column to type datetime
    df['created_at'] = pd.to_datetime(df['created_at'])

    # Remove any tweets before earliest allowed date
    df = df[df['created_at'] >= min_date]

    # Drop duplicates and print number of rows removed as duplicates
    rows_start = len(df)
    df.sort_values(by=['created_at', 
                       'retweet_count', 
                       'favorite_count', 
                       'user_friends_count',
                       'user_followers_count', 
                       'user_favourites_count',
                       'user_statuses_count'], 
                   ascending=[True, False, False, False, False, False, False], 
                   ignore_index=True,
                   inplace=True)
    df.drop_duplicates(subset=['created_at', 'text', 'user_id'], 
                       inplace=True)
    rows_end = len(df)
    print('Number of Duplicate Rows Removed:', rows_start-rows_end)

    # Return the final dataframe
    return df

# %% [markdown]
# **General Election Data:**

# %%
# Concatonate and dedup election datasets
election_df = handle_datasets(election_files, earliest_date)

# See shape and head of dataframe
print('Election Dataframe Shape:', election_df.shape)
election_df.head(3)
# Out:
# Number of Duplicate Rows Removed: 739
# Election Dataframe Shape: (3795, 20)
#            created_at                                               text  \
# 0 2022-10-17 08:10:19           Looks like c-span is carrying it live. ,
# 1 2022-10-17 08:16:09  Georgia just became the latest state to requir...
# 2 2022-10-17 08:17:18  With the Governor election just weeks away, a ...
#
#                             hashtags       user_mention_ids  \
# 0                                 []  [1553531142321709056]
# 1                            ['rxa']                     []
# 2  ['Georgia', 'Democrat', 'BLEXIT']            [216065430]
#
#   user_mention_screen_names  retweet_count  favorite_count  \
# 0          ['CaseyReber35']              0               1
# 1                        []              0               0
# 2          ['staceyabrams']              0               0
#
#    in_reply_to_user_id in_reply_to_screen_name  geo coordinates  \
# 0         1.553531e+18            CaseyReber35  NaN         NaN
# 1                  NaN                     NaN  NaN         NaN
# 2                  NaN                     NaN  NaN         NaN
#
#                user_id user_screen_name  \
# 0   754913164827959300         WahcaMia
# 1            757814965       KinteSpace
# 2  1519406689451184129  EddieTarazonaFL
#
#                                            user_name            user_location  \
# 0  MiaMarie #TeamShapiroBetoAbramsDemingsMcMullin...  On a Mountain Somewhere
# 1                                    the kinte space              Los Angeles
# 2                                     Eddie Tarazona             Florida, USA
#
#    user_friends_count  user_followers_count  user_favourites_count  \
# 0                5467                  5743                 291152
# 1                 300                   480                     28
# 2                 629                    88                    608
#
#    user_verfied  user_statuses_count
# 0         False               253115
# 1         False                30228
# 2         False                 1952

# %% [markdown]
# **Abrams Data:**

# %%
# Concatonate and dedup abrams datasets
abrams_df = handle_datasets(abrams_files, earliest_date)

# See shape and head of dataframe
print('Abrams Dataframe Shape:', abrams_df.shape)
abrams_df.head(3)
# Out:
# Number of Duplicate Rows Removed: 5564
# Abrams Dataframe Shape: (26535, 20)
#            created_at                                               text  \
# 0 2022-10-17 08:12:17                     Oh great another Stacey Abrams
# 1 2022-10-17 08:17:39  Stacey Abrams took Kemp to court over his canc...
# 2 2022-10-17 08:24:36  Barack Obama to host October midterm rallies t...
#
#   hashtags user_mention_ids user_mention_screen_names  retweet_count  \
# 0       []         [759251]                   ['CNN']              0
# 1       []       [91882544]          ['DineshDSouza']              0
# 2       []               []                        []              0
#
#    favorite_count  in_reply_to_user_id in_reply_to_screen_name  geo  \
# 0               0             759251.0                     CNN  NaN
# 1               0           91882544.0            DineshDSouza  NaN
# 2               0                  NaN                     NaN  NaN
#
#   coordinates              user_id user_screen_name  \
# 0         NaN  1307710729957437440   michael_rah_SF
# 1         NaN           2729832932        KalDraken
# 2         NaN           1963887212          Fam4Fun
#
#                     user_name    user_location  user_friends_count  \
# 0  Low-intensity High-perdiem              NaN                 298
# 1                   KalDraken              NaN                  93
# 2                     KP🙌🏿💙🙌🏻  California, USA                3172
#
#    user_followers_count  user_favourites_count  user_verfied  \
# 0                    37                   5983         False
# 1                   111                   6791         False
# 2                  3865                 183381         False
#
#    user_statuses_count
# 0                 3501
# 1                 2359
# 2                46788

# %% [markdown]
# **Kemp Data:**

# %%
# Concatonate and dedup kemp datasets
kemp_df = handle_datasets(kemp_files, earliest_date)

# See shape and head of dataframe
print('Kemp Dataframe Shape:', kemp_df.shape)
kemp_df.head(3)
# Out:
# Number of Duplicate Rows Removed: 1411
# Kemp Dataframe Shape: (7958, 20)
#            created_at                                               text  \
# 0 2022-10-17 08:16:09  Georgia just became the latest state to requir...
# 1 2022-10-17 09:02:31  Brian Kemp to battle Stacey Abrams in gubernat...
# 2 2022-10-17 09:14:47  HOW MANY GEORGIANS DIE EACH YEAR DUE TO GOVERN...
#
#   hashtags                            user_mention_ids  \
# 0  ['rxa']                                          []
# 1       []                                  [10228272]
# 2       []  [739844197935644672, 612557998, 216065430]
#
#                          user_mention_screen_names  retweet_count  \
# 0                                               []              0
# 1                                      ['YouTube']              0
# 2  ['AmoneyResists', 'ccharlamb8', 'staceyabrams']              0
#
#    favorite_count  in_reply_to_user_id in_reply_to_screen_name  geo  \
# 0               0                  NaN                     NaN  NaN
# 1               0                  NaN                     NaN  NaN
# 2               0           26241121.0          FirstJamesBond  NaN
#
#   coordinates     user_id user_screen_name             user_name  \
# 0         NaN   757814965       KinteSpace       the kinte space
# 1         NaN  3193701535       lklonelove  Lawrence K Lancaster
# 2         NaN    26241121   FirstJamesBond              Jim Bond
#
#      user_location  user_friends_count  user_followers_count  \
# 0      Los Angeles                 300                   480
# 1  Los Angeles, CA                4318                  1556
# 2    Dallas, Texas                3006                   756
#
#    user_favourites_count  user_verfied  user_statuses_count
# 0                     28         False                30222
# 1                     28         False                12896
# 2                  23094         False                60100

# %% [markdown]
# #### Combine all dataframes and dedup

# %%
# Concatonate all dataframes
all_df = pd.concat([election_df,abrams_df,kemp_df])

# Deduplicate rows
rows_start = len(all_df)
all_df.sort_values(by=['created_at', 
                       'retweet_count', 
                       'favorite_count', 
                       'user_friends_count',
                       'user_followers_count', 
                       'user_favourites_count',
                       'user_statuses_count'], 
                   ascending=[True, False, False, False, False, False, False], 
                   ignore_index=True,
                   inplace=True)
all_df.drop_duplicates(subset=['created_at', 'text', 'user_id'], 
                       inplace=True)
rows_end = len(all_df)
print('Number of Duplicate Rows Removed:', rows_start-rows_end)

# Get all data's shape
print('All Dataframe Shape:', all_df.shape)
# Out:
# Number of Duplicate Rows Removed: 4071
# All Dataframe Shape: (34217, 20)

# %% [markdown]
# #### Save all dataframes to csvs

# %%
election_df.to_csv('election_data.csv')
abrams_df.to_csv('abrams_data.csv')
kemp_df.to_csv('kemp_data.csv')
all_df.to_csv('all_data.csv')
